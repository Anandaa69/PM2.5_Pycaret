# %%
import pycaret
import pandas as pd

# %%
# อ่านไฟล์ CSV
data = pd.read_csv('export_data/filtered_data_3_best.csv')

# %%
# ตั้ง 'timestamp' เป็น index หากยังไม่ได้ทำ
data['timestamp'] = pd.to_datetime(data['timestamp'])
data.set_index('timestamp', inplace=True)

# ตั้งค่า freq ให้กับ index
data = data.asfreq('D')  # 'D' สำหรับรายวัน

# %%
# แสดงแถวที่มีค่าหายไปก่อนเติม
print("แถวที่มีค่าหายไปก่อนเติม:")
print(data[data.isnull().any(axis=1)])

# เติมค่าที่หายไปด้วยการ interpolate แบบเส้นตรง
data.interpolate(method='linear', inplace=True)

# แสดงแถวที่ยังมีค่า NaN หลังจากเติม (ถ้ามี)
missing_rows_after = data[data.isnull().any(axis=1)]
if not missing_rows_after.empty:
    print("แถวที่ยังมีค่าหายไปหลังเติม:")
    print(missing_rows_after)
else:
    print("ไม่มีค่าหายไปแล้ว")

row = data.loc["2023-09-30 07:00:00"]
row
# Out:
# แถวที่มีค่าหายไปก่อนเติม:
#                      humidity  pm_10  pm_2_5  pm_2_5_sp  temperature
# timestamp
# 2023-09-30 07:00:00       NaN    NaN     NaN        NaN          NaN
# ไม่มีค่าหายไปแล้ว
# humidity       82.889367
# pm_10          60.525519
# pm_2_5         53.415241
# pm_2_5_sp      69.527667
# temperature    29.219760
# Name: 2023-09-30 07:00:00, dtype: float64

# %%
data = data[['pm_10', 'humidity', 'temperature']]

# %%
data["year"] = data.index.year
data["month"] = data.index.month
data["day"] = data.index.day
data["day_of_week"] = data.index.dayofweek  # 0 = Monday, 6 = Sunday
data["week_of_year"] = data.index.isocalendar().week  # ค่าจะเป็น int64

# %%
# สมมติว่า data มี index เป็น datetime อยู่แล้ว
def assign_season(month):
    if month in [2, 3, 4]:  # ก.พ. - เม.ย.
        return "summer"        # ฤดูร้อน
    elif month in [5, 6, 7]:  # พ.ค. - ก.ค.
        return "early_rainy"   # ต้นฤดูฝน
    else:  # ส.ค. - ม.ค.
        return "late_rainy"    # ปลายฤดูฝน

season_mapping = {'summer': 0, 'early_rainy': 1, 'late_rainy': 2}
data["season"] = data.index.month.map(assign_season)
data['season'] = data['season'].map(season_mapping)

# %%
data['dew_point'] = data['temperature'] - ((100 - data['humidity']) / 5)

# %%
data["is_weekend"] = data.index.dayofweek.isin([5, 6]).astype(int)

# %%
# อัตราส่วนของอุณหภูมิต่อความชื้น
data["temp_humidity_ratio"] = data["temperature"] / (data["humidity"] + 1)

# %%
# ดัชนีความร้อน (Heat Index) หรืออุณหภูมิที่รับรู้
T = data["temperature"]
RH = data["humidity"]

data["heat_index"] = -42.379 + (2.04901523 * T) + (10.14333127 * RH) - (0.22475541 * T * RH) - \
                   (0.00683783 * T**2) - (0.05481717 * RH**2) + (0.00122874 * T**2 * RH) + \
                   (0.00085282 * T * RH**2) - (0.00000199 * T**2 * RH**2)

# %%
# ความชื้นสัมพัทธ์เชิงดัชนี
data["rh_index"] = data["humidity"] ** 2 / (data["temperature"] + 1)

# %%
# #4. ค่าเฉลี่ยของ Humidity และ Temperature ของวันก่อนหน้า
# df["humidity_prev_day"] = df["humidity"].shift(1)
# df["temperature_prev_day"] = df["temperature"].shift(1)

# %%
# import pandas as pd
# import numpy as np

# # สมมุติว่ามี DataFrame data ที่มีข้อมูลอยู่แล้ว

# # เพิ่มฟีเจอร์ day_of_year
# data['day_of_year'] = data['month'] * 30 + data['day']  # คำนวณวันในปี

# # เพิ่มฟีเจอร์ hour_of_day (สมมุติว่าเป็นข้อมูลที่มีชั่วโมง)
# # หากไม่มีข้อมูลชั่วโมงใน data, อาจต้องใส่ฟีเจอร์นี้เพิ่มเติม
# # data['hour_of_day'] = data['hour']

# # เพิ่มฟีเจอร์ is_holiday (สามารถกำหนดเองได้)
# # สมมุติว่าคุณมีรายชื่อวันหยุดในปีนั้นๆ
# # holidays = ['2025-01-01', '2025-12-25']  # ตัวอย่าง
# # data['date'] = pd.to_datetime(data[['year', 'month', 'day']])
# # data['is_holiday'] = data['date'].isin(pd.to_datetime(holidays))

# # เพิ่มฟีเจอร์ month_sin และ month_cos
# data['month_sin'] = np.sin(2 * np.pi * data['month'] / 12)
# data['month_cos'] = np.cos(2 * np.pi * data['month'] / 12)

# # เพิ่มฟีเจอร์ day_of_week_sin และ day_of_week_cos
# data['day_of_week_sin'] = np.sin(2 * np.pi * data['day_of_week'] / 7)
# data['day_of_week_cos'] = np.cos(2 * np.pi * data['day_of_week'] / 7)

# # เพิ่มฟีเจอร์ rolling average (ค่าเฉลี่ยเคลื่อนที่)
# data['pm_10_rolling_2'] = data['pm_10'].shift(1).rolling(window=2).mean()  # ค่าเฉลี่ย 2 วันของ PM 10
# data['pm_10_rolling_3'] = data['pm_10'].shift(1).rolling(window=3).mean()  # ค่าเฉลี่ย 3 วันของ PM 10
# data['pm_10_rolling_5'] = data['pm_10'].shift(1).rolling(window=5).mean()  # ค่าเฉลี่ย 5 วันของ PM 10
# data['pm_10_rolling_7'] = data['pm_10'].shift(1).rolling(window=7).mean()  # ค่าเฉลี่ย 7 วันของ PM 10

# data['pm_10_lag_1'] = data['pm_10'].shift(1)
# data['pm_10_lag_2'] = data['pm_10'].shift(2)
# data['pm_10_lag_3'] = data['pm_10'].shift(3)
# data['pm_10_lag_5'] = data['pm_10'].shift(5)
# data['pm_10_lag_7'] = data['pm_10'].shift(7)

# data['humidity_rolling_2'] = data['humidity'].shift(1).rolling(window=2).mean()  # ค่าเฉลี่ย 2 วันของ PM 10
# data['humidity_rolling_3'] = data['humidity'].shift(1).rolling(window=3).mean()  # ค่าเฉลี่ย 3 วันของ PM 10
# data['humidity_rolling_5'] = data['humidity'].shift(1).rolling(window=5).mean()  # ค่าเฉลี่ย 5 วันของ PM 10
# data['humidity_rolling_7'] = data['humidity'].shift(1).rolling(window=7).mean()  # ค่าเฉลี่ย 7 วันของ PM 10

# data['humidity_lag_1'] = data['humidity'].shift(1)
# data['humidity_lag_2'] = data['humidity'].shift(2)
# data['humidity_lag_3'] = data['humidity'].shift(3)
# data['humidity_lag_5'] = data['humidity'].shift(5)
# data['humidity_lag_7'] = data['humidity'].shift(7)

# data['temperature_rolling_2'] = data['temperature'].shift(1).rolling(window=2).mean()  # ค่าเฉลี่ย 2 วันของ PM 10
# data['temperature_rolling_3'] = data['temperature'].shift(1).rolling(window=3).mean()  # ค่าเฉลี่ย 3 วันของ PM 10
# data['temperature_rolling_5'] = data['temperature'].shift(1).rolling(window=5).mean()  # ค่าเฉลี่ย 5 วันของ PM 10
# data['temperature_rolling_7'] = data['temperature'].shift(1).rolling(window=7).mean()  # ค่าเฉลี่ย 7 วันของ PM 10

# data['temperature_lag_1'] = data['temperature'].shift(1)
# data['temperature_lag_2'] = data['temperature'].shift(2)
# data['temperature_lag_3'] = data['temperature'].shift(3)
# data['temperature_lag_5'] = data['temperature'].shift(5)
# data['temperature_lag_7'] = data['temperature'].shift(7)

# data.dropna(subset=["pm_10_last_week"], inplace=True)  # ลบแถวที่ไม่มีค่า PM2.5 Last Week
# # data['humidity_rolling'] = data['humidity'].rolling(window=5).mean()  # ค่าเฉลี่ย 7 วันของความชื้น
# # data['temperature_rolling'] = data['temperature'].rolling(window=5).mean()

# # # ตรวจสอบว่า DataFrame พร้อมใช้งานแล้ว
# # print(data.head())

# %%
import pandas as pd
import numpy as np

# สมมุติว่ามี DataFrame data ที่มีข้อมูลอยู่แล้ว

# เพิ่มฟีเจอร์ day_of_year
data['date'] = pd.to_datetime(data[['year', 'month', 'day']])
data['day_of_year'] = data['date'].dt.dayofyear

# เพิ่มฟีเจอร์ hour_of_day (สมมุติว่าเป็นข้อมูลที่มีชั่วโมง)
# หากไม่มีข้อมูลชั่วโมงใน data, อาจต้องใส่ฟีเจอร์นี้เพิ่มเติม
# data['hour_of_day'] = data['hour']

# เพิ่มฟีเจอร์ is_holiday (สามารถกำหนดเองได้)
# สมมุติว่าคุณมีรายชื่อวันหยุดในปีนั้นๆ
# holidays = ['2025-01-01', '2025-12-25']  # ตัวอย่าง
# data['date'] = pd.to_datetime(data[['year', 'month', 'day']])
# data['is_holiday'] = data['date'].isin(pd.to_datetime(holidays))

# เพิ่มฟีเจอร์ month_sin และ month_cos
data['month_sin'] = np.sin(2 * np.pi * data['month'] / 12)
data['month_cos'] = np.cos(2 * np.pi * data['month'] / 12)

# เพิ่มฟีเจอร์ day_of_week_sin และ day_of_week_cos
data['day_of_week_sin'] = np.sin(2 * np.pi * data['day_of_week'] / 7)
data['day_of_week_cos'] = np.cos(2 * np.pi * data['day_of_week'] / 7)

# เพิ่มฟีเจอร์ rolling average (ค่าเฉลี่ยเคลื่อนที่)
data['pm_10_rolling_2'] = data['pm_10'].rolling(window=2).mean().shift(1)  # ค่าเฉลี่ย 2 วันของ PM 10
data['pm_10_rolling_3'] = data['pm_10'].rolling(window=3).mean().shift(1)  # ค่าเฉลี่ย 3 วันของ PM 10
data['pm_10_rolling_5'] = data['pm_10'].rolling(window=5).mean().shift(1)  # ค่าเฉลี่ย 5 วันของ PM 10
data['pm_10_rolling_7'] = data['pm_10'].rolling(window=7).mean().shift(1)

data['pm_10_lag_1'] = data['pm_10'].shift(1)
data['pm_10_lag_2'] = data['pm_10'].shift(2)
data['pm_10_lag_3'] = data['pm_10'].shift(3)
data['pm_10_lag_5'] = data['pm_10'].shift(5)
data['pm_10_lag_7'] = data['pm_10'].shift(7)

data['humidity_rolling_2'] = data['humidity'].rolling(window=2).mean().shift(1)  # ค่าเฉลี่ย 2 วันของ PM 10
data['humidity_rolling_3'] = data['humidity'].rolling(window=3).mean().shift(1)  # ค่าเฉลี่ย 3 วันของ PM 10
data['humidity_rolling_5'] = data['humidity'].rolling(window=5).mean().shift(1)  # ค่าเฉลี่ย 5 วันของ PM 10
data['humidity_rolling_7'] = data['humidity'].rolling(window=7).mean().shift(1)  # ค่าเฉลี่ย 7 วันของ PM 10

data['humidity_lag_1'] = data['humidity'].shift(1)
data['humidity_lag_2'] = data['humidity'].shift(2)
data['humidity_lag_3'] = data['humidity'].shift(3)
data['humidity_lag_5'] = data['humidity'].shift(5)
data['humidity_lag_7'] = data['humidity'].shift(7)

data['temperature_rolling_2'] = data['temperature'].rolling(window=2).mean().shift(1)  # ค่าเฉลี่ย 2 วันของ PM 10
data['temperature_rolling_3'] = data['temperature'].rolling(window=3).mean().shift(1)  # ค่าเฉลี่ย 3 วันของ PM 10
data['temperature_rolling_5'] = data['temperature'].rolling(window=5).mean().shift(1)  # ค่าเฉลี่ย 5 วันของ PM 10
data['temperature_rolling_7'] = data['temperature'].rolling(window=7).mean().shift(1)  # ค่าเฉลี่ย 7 วันของ PM 10

data['temperature_lag_1'] = data['temperature'].shift(1)
data['temperature_lag_2'] = data['temperature'].shift(2)
data['temperature_lag_3'] = data['temperature'].shift(3)
data['temperature_lag_5'] = data['temperature'].shift(5)
data['temperature_lag_7'] = data['temperature'].shift(7)

data.dropna(subset=["pm_10_rolling_7"], inplace=True)  # ลบแถวที่ไม่มีค่า PM2.5 Last Week
# data['humidity_rolling'] = data['humidity'].rolling(window=5).mean()  # ค่าเฉลี่ย 7 วันของความชื้น
# data['temperature_rolling'] = data['temperature'].rolling(window=5).mean()

# # ตรวจสอบว่า DataFrame พร้อมใช้งานแล้ว
# print(data.head())

# %%
data["temp_diff"] = data["temperature"].diff()
data["humidity_diff"] = data["humidity"].diff()

# %%
data.columns
# Out:
# Index(['pm_10', 'humidity', 'temperature', 'year', 'month', 'day',
#        'day_of_week', 'week_of_year', 'season', 'dew_point', 'is_weekend',
#        'temp_humidity_ratio', 'heat_index', 'rh_index', 'date', 'day_of_year',
#        'month_sin', 'month_cos', 'day_of_week_sin', 'day_of_week_cos',
#        'pm_10_rolling_2', 'pm_10_rolling_3', 'pm_10_rolling_5',
#        'pm_10_rolling_7', 'pm_10_lag_1', 'pm_10_lag_2', 'pm_10_lag_3',
#        'pm_10_lag_5', 'pm_10_lag_7', 'humidity_rolling_2',
#        'humidity_rolling_3', 'humidity_rolling_5', 'humidity_rolling_7',
#        'humidity_lag_1', 'humidity_lag_2', 'humidity_lag_3', 'humidity_lag_5',
#        'humidity_lag_7', 'temperature_rolling_2', 'temperature_rolling_3',
#        'temperature_rolling_5', 'temperature_rolling_7', 'temperature_lag_1',
#        'temperature_lag_2', 'temperature_lag_3', 'temperature_lag_5',
#        'temperature_lag_7', 'temp_diff', 'humidity_diff'],
#       dtype='object')

# %%
data_filtered = data.loc['2023-09':]  # ดึงข้อมูลตั้งแต่กันยายน 2023 เป็นต้นไป

# %%
data_filtered.plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
# สมมติว่า data มีจำนวนวันทั้งหมด
total_data = len(data_filtered)

# จำนวนวันที่ต้องการเป็น test data
test_days = 30

# คำนวณสัดส่วนของ 30 วันในข้อมูลทั้งหมด
test_size = test_days / total_data
test_size
# Out:
# 0.05660377358490566

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(data_filtered, test_size=test_size, shuffle=False)

# %%
train_data.shape
# Out:
# (500, 49)

# %%
test_data.shape
# Out:
# (30, 49)

# %%
# ADD
test_data = test_data.iloc[[0]]

# %%
test_data
# Out:
#                          pm_10   humidity  temperature  year  month  day  \
# timestamp
# 2025-01-13 07:00:00  48.632215  78.292202    25.997341  2025      1   13
#
#                      day_of_week  week_of_year  season  dew_point  ...  \
# timestamp                                                          ...
# 2025-01-13 07:00:00            0             3       2  21.655782  ...
#
#                      temperature_rolling_3  temperature_rolling_5  \
# timestamp
# 2025-01-13 07:00:00              27.579379              28.008569
#
#                      temperature_rolling_7  temperature_lag_1  \
# timestamp
# 2025-01-13 07:00:00              28.287636          25.434972
#
#                     temperature_lag_2  temperature_lag_3  temperature_lag_5  \
# timestamp
# 2025-01-13 07:00:00         28.357459          28.945704          28.921543
#
#                      temperature_lag_7  temp_diff  humidity_diff
# timestamp
# 2025-01-13 07:00:00          28.825509   0.562369      -7.087604
#
# [1 rows x 49 columns]

# %%
test_data.tail()
# Out:
#                          pm_10   humidity  temperature  year  month  day  \
# timestamp
# 2025-01-13 07:00:00  48.632215  78.292202    25.997341  2025      1   13
#
#                      day_of_week  week_of_year  season  dew_point  ...  \
# timestamp                                                          ...
# 2025-01-13 07:00:00            0             3       2  21.655782  ...
#
#                      temperature_rolling_3  temperature_rolling_5  \
# timestamp
# 2025-01-13 07:00:00              27.579379              28.008569
#
#                      temperature_rolling_7  temperature_lag_1  \
# timestamp
# 2025-01-13 07:00:00              28.287636          25.434972
#
#                     temperature_lag_2  temperature_lag_3  temperature_lag_5  \
# timestamp
# 2025-01-13 07:00:00         28.357459          28.945704          28.921543
#
#                      temperature_lag_7  temp_diff  humidity_diff
# timestamp
# 2025-01-13 07:00:00          28.825509   0.562369      -7.087604
#
# [1 rows x 49 columns]

# %%
test_data.columns
# Out:
# Index(['pm_10', 'humidity', 'temperature', 'year', 'month', 'day',
#        'day_of_week', 'week_of_year', 'season', 'dew_point', 'is_weekend',
#        'temp_humidity_ratio', 'heat_index', 'rh_index', 'date', 'day_of_year',
#        'month_sin', 'month_cos', 'day_of_week_sin', 'day_of_week_cos',
#        'pm_10_rolling_2', 'pm_10_rolling_3', 'pm_10_rolling_5',
#        'pm_10_rolling_7', 'pm_10_lag_1', 'pm_10_lag_2', 'pm_10_lag_3',
#        'pm_10_lag_5', 'pm_10_lag_7', 'humidity_rolling_2',
#        'humidity_rolling_3', 'humidity_rolling_5', 'humidity_rolling_7',
#        'humidity_lag_1', 'humidity_lag_2', 'humidity_lag_3', 'humidity_lag_5',
#        'humidity_lag_7', 'temperature_rolling_2', 'temperature_rolling_3',
#        'temperature_rolling_5', 'temperature_rolling_7', 'temperature_lag_1',
#        'temperature_lag_2', 'temperature_lag_3', 'temperature_lag_5',
#        'temperature_lag_7', 'temp_diff', 'humidity_diff'],
#       dtype='object')

# %%
# from pycaret.time_series import *
from pycaret.regression import RegressionExperiment
exp1 = RegressionExperiment()
exp1.setup(data=train_data, target='pm_10', session_id=123,test_data=test_data, fold=12)
# Out:
# <style type="text/css">
# #T_aa742_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_aa742">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa742_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_aa742_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa742_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aa742_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_aa742_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aa742_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_aa742_row1_col1" class="data row1 col1" >pm_10</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aa742_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_aa742_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aa742_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_aa742_row3_col1" class="data row3 col1" >(501, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aa742_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_aa742_row4_col1" class="data row4 col1" >(501, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_aa742_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_aa742_row5_col1" class="data row5 col1" >(500, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_aa742_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_aa742_row6_col1" class="data row6 col1" >(1, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_aa742_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_aa742_row7_col1" class="data row7 col1" >47</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_aa742_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_aa742_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_aa742_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_aa742_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_aa742_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_aa742_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_aa742_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_aa742_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_aa742_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_aa742_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_aa742_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_aa742_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_aa742_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_aa742_row14_col1" class="data row14 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_aa742_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_aa742_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_aa742_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_aa742_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_aa742_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_aa742_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_aa742_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_aa742_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_aa742_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_aa742_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_aa742_row19_col1" class="data row19 col1" >29e8</td>
#     </tr>
#   </tbody>
# </table>

# %%
# compare baseline models
best = exp1.compare_models(n_select=17)
# Out:
# <style type="text/css">
# #T_b3c94 th {
#   text-align: left;
# }
# #T_b3c94_row0_col0, #T_b3c94_row0_col1, #T_b3c94_row0_col2, #T_b3c94_row0_col3, #T_b3c94_row0_col5, #T_b3c94_row0_col6, #T_b3c94_row1_col0, #T_b3c94_row1_col1, #T_b3c94_row1_col4, #T_b3c94_row1_col5, #T_b3c94_row1_col6, #T_b3c94_row2_col0, #T_b3c94_row2_col1, #T_b3c94_row2_col2, #T_b3c94_row2_col3, #T_b3c94_row2_col4, #T_b3c94_row2_col5, #T_b3c94_row2_col6, #T_b3c94_row3_col0, #T_b3c94_row3_col1, #T_b3c94_row3_col2, #T_b3c94_row3_col3, #T_b3c94_row3_col4, #T_b3c94_row3_col5, #T_b3c94_row3_col6, #T_b3c94_row4_col0, #T_b3c94_row4_col1, #T_b3c94_row4_col2, #T_b3c94_row4_col3, #T_b3c94_row4_col4, #T_b3c94_row4_col5, #T_b3c94_row4_col6, #T_b3c94_row5_col0, #T_b3c94_row5_col2, #T_b3c94_row5_col3, #T_b3c94_row5_col4, #T_b3c94_row6_col
row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_b3c94_row5_col1" class="data row5 col1" >5.6131</td>
#       <td id="T_b3c94_row5_col2" class="data row5 col2" >56.4153</td>
#       <td id="T_b3c94_row5_col3" class="data row5 col3" >7.2578</td>
#       <td id="T_b3c94_row5_col4" class="data row5 col4" >0.2845</td>
#       <td id="T_b3c94_row5_col5" class="data row5 col5" >0.3314</td>
#       <td id="T_b3c94_row5_col6" class="data row5 col6" >0.2934</td>
#       <td id="T_b3c94_row5_col7" class="data row5 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_b3c94_level0_row6" class="row_heading l

# %% [markdown]
# # fold=5
# fold = 9 == 0.4985
# fold = 10 == 0.4819

# %%
# pred_holdout = exp1.predict_model(best)

# %%
model_1 = exp1.create_model('huber')
# Out:
# <style type="text/css">
# #T_c8487_row12_col0, #T_c8487_row12_col1, #T_c8487_row12_col2, #T_c8487_row12_col3, #T_c8487_row12_col4, #T_c8487_row12_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c8487">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8487_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c8487_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c8487_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c8487_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c8487_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c8487_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8487_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8487_row0_col0" class="data row0 col0" >7.6843</td>
#       <td id="T_c8487_row0_col1" class="data row0 col1" >112.6044</td>
#       <td id="T_c8487_row0_col2" class="data row0 col2" >10.6115</td>
#       <td id="T_c8487_row0_col3" class="data row0 col3" >0.4777</td>
#       <td id="T_c8487_row0_col4" class="data row0 col4" >0.3763</td>
#       <td id="T_c8487_row0_col5" class="data row0 col5" >0.2885</td>
#     </tr>
#     <tr>
#       <th id="T_c8487_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8487_row1_col0" class="data row1 col0" >4.9519</td>
#       <td id="T_c8487_row1_col1" class="data row1 col1" >37.1379</td>
#       <td id="T_c8487_row1_col2" class="data row1 col2" >6.0941</td>
#       <td id="T_c8487_row1_col3" class="data row1 col3" >0.1165</td>
#       <td id="T_c8487_row1_col4" class="data row1 col4" >0.3487</td>
#       <td id="T_c8487_row1_col5" class="data row1 col5" >0.3191</td>
#     </tr>
#     <tr>
#       <th id="T_c8487_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c8487_row2_col0" class="data row2 col0" >3.4852</td>
#       <td id="T_c8487_row2_col1" class="data row2 col1" >21.5901</td>
#       <td id="T_c8487_row2_col2" class="data row2 col2" >4.6465</td>
#       <td id="T_c8487_row2_col3" class="data row2 col3" >0.4996</td>
#       <td id="T_c8487_row2_col4" class="data row2 col4" >0.2819</td>
#       <td id="T_c8487_row2_col5" class="data row2 col5" >0.2548</td>
#     </tr>
#     <tr>
#       <th id="T_c8487_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c8487_row3_col0" class="data row3 col0" >3.9917</td>
#       <td id="T_c8487_row3_col1" class="data row3 col1" >31.9216</td>
#       <td id="T_c8487_row3_col2" class="data row3 col2" >5.6499</td>
#       <td id="T_c8487_row3_col3" class="data row3 col3" >0.1630</td>
#       <td id="T_c8487_row3_col4" class="data row3 col4" >0.2131</td>
#       <td id="T_c8487_row3_col5" class="data row3 col5" >0.1613</td>
#     </tr>
#     <tr>
#       <th id="T_c8487_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c8487_row4_col0" class="data row4 col0" >5.5528</td>
#       <td id="T_c8487_row4_col1" class="data row4 col1" >49.7784</td>
#       <td id="T_c8487_row4_col2" class="data row4 col2" >7.0554</td>
#       <td id="T_c8487_row4_col3" class="data row4 col3" >0.2504</td>
#       <td id="T_c8487_row4_col4" class="data row4 col4" >0.2792</td>
#       <td id="T_c8487_row4_col5" class="data row4 col5" >0.2400</td>
#     </tr>
#     <tr>
#       <th id="T_c8487_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c8487_row5_col0" class="data row5 col0" >5.3226</td>
#       <td id="T_c8487_row5_col1" class="data row5 col1" >42.4838</td>
#       <td id="T_c8487_row5_col2" class="data row5 col2" >6.5180</td>
#       <td id="T_c8487_row5_col3" class="data row5 col3" >0.2175</td>
#       <td id="T_c8487_row5_col4" class="data row5 col4" >0.2237</td>
#       <td id="T_c8487_row5_col5" class="data row5 col5" >0.1933</td>
#     </tr>
#     <tr>
#       <th id="T_c8487_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c8487_row6_col0" class="data row6 col0" >5.8314</td>
#       <td id="T_c8487_row6_col1" class="data row6 col1" >51.4869</td>
#       <td id="T_c8487_row6_col2" class="data row6 col2" >7.1754</td>
#       <td id="T_c8487_row6_col3" class="data row6 col3" >0.4609</td>
#       <td id="T_c8487_row6_col4" class="data row6 col4" >0.2880</td>
#       <td id="T_c8487_row6_col5" class="data row6 col5" >0.2825</td>
#     </tr>
#     <tr>
#       <th id="T_c8487_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c8487_row7_col0" class="data row7 col0" >8.6670</td>
#       <td id="T_c8487_row7_col1" class="data row7 col1" >137.6620</td>
#       <td id="T_c8487_row7_col2" class="data row7 col2" >11.7329</td>
#       <td id="T_c8487_row7_col3" class="data row7 col3" >0.3847</td>
#       <td id="T_c8487_row7_col4" class="data row7 col4" >0.3556</td>
#       <td id="T_c8487_row7_col5" class="data row7 col5" >0.2847</td>
#     </tr>
#     <tr>
#       <th id="T_c8487_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c8487_row8_col0" class="data row8 col0" >5.2943</td>
#       <td id="T_c8487_row8_col1" class="data row8 col1" >40.2835</td>
#       <td id="T_c8487_row8_col2" class="data row8 col2" >6.3469</td>
#       <td id="T_c8487_row8_col3" class="data row8 col3" >0.5633</td>
#       <td id="T_c8487_row8_col4" class="data row8 col4" >0.3277</td>
#       <td id="T_c8487_row8_col5" class="data row8 col5" >0.3120</td>
#     </tr>
#     <tr>
#       <th id="T_c8487_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c8487_row9_col0" class="data row9 col0" >5.3238</td>
#       <td id="T_c8487_row9_col1" class="data row9 col1" >46.8528</td>
#       <td id="T_c8487_row9_col2" class="data row9 col2" >6.8449</td>
#       <td id="T_c8487_row9_col3" class="data row9 col3" >-0.2595</td>
#       <td id="T_c8487_row9_col4" class="data row9 col4" >0.3845</td>
#       <td id="T_c8487_row9_col5" class="data row9 col5" >0.3458</td>
#     </tr>
#     <tr>
#       <th id="T_c8487_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c8487_row10_col0" class="data row10 col0" >5.0258</td>
#       <td id="T_c8487_row10_col1" class="data row10 col1" >41.2149</td>
#       <td id="T_c8487_row10_col2" class="data row10 col2" >6.4199</td>
#       <td id="T_c8487_row10_col3" class="data row10 col3" >0.0516</td>
#       <td id="T_c8487_row10_col4" class="data row10 col4" >0.5061</td>
#       <td id="T_c8487_row10_col5" class="data row10 col5" >0.5147</td>
#     </tr>
#     <tr>
#       <th id="T_c8487_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c8487_row11_col0" class="data row11 col0" >6.2260</td>
#       <td id="T_c8487_row11_col1" class="data row11 col1" >63.9678</td>
#       <td id="T_c8487_row11_col2" class="data row11 col2" >7.9980</td>
#       <td id="T_c8487_row11_col3" class="data row11 col3" >0.4882</td>
#       <td id="T_c8487_row11_col4" class="data row11 col4" >0.3919</td>
#       <td id="T_c8487_row11_col5" class="data row11 col5" >0.3242</td>
#     </tr>
#     <tr>
#       <th id="T_c8487_level0_row12" class="row_heading level0 row12" >Mean</th>
#       <td id="T_c8487_row12_col0" class="data row12 col0" >5.6131</td>
#       <td id="T_c8487_row12_col1" class="data row12 col1" >56.4153</td>
#       <td id="T_c8487_row12_col2" class="data row12 col2" >7.2578</td>
#       <td id="T_c8487_row12_col3" class="data row12 col3" >0.2845</td>
#       <td id="T_c8487_row12_col4" class="data row12 col4" >0.3314</td>
#       <td id="T_c8487_row12_col5" class="data row12 col5" >0.2934</td>
#     </tr>
#     <tr>
#       <th id="T_c8487_level0_row13" class="row_heading level0 row13" >Std</th>
#       <td id="T_c8487_row13_col0" class="data row13 col0" >1.3617</td>
#       <td id="T_c8487_row13_col1" class="data row13 col1" >32.7170</td>
#       <td id="T_c8

# %%
exp1.evaluate_model(model_1)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
tune_1 = exp1.tune_model(model_1)
# Out:
# <style type="text/css">
# #T_8d222_row12_col0, #T_8d222_row12_col1, #T_8d222_row12_col2, #T_8d222_row12_col3, #T_8d222_row12_col4, #T_8d222_row12_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8d222">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d222_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8d222_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8d222_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8d222_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8d222_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8d222_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d222_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d222_row0_col0" class="data row0 col0" >7.6516</td>
#       <td id="T_8d222_row0_col1" class="data row0 col1" >109.7183</td>
#       <td id="T_8d222_row0_col2" class="data row0 col2" >10.4747</td>
#       <td id="T_8d222_row0_col3" class="data row0 col3" >0.4911</td>
#       <td id="T_8d222_row0_col4" class="data row0 col4" >0.3796</td>
#       <td id="T_8d222_row0_col5" class="data row0 col5" >0.2888</td>
#     </tr>
#     <tr>
#       <th id="T_8d222_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8d222_row1_col0" class="data row1 col0" >4.9150</td>
#       <td id="T_8d222_row1_col1" class="data row1 col1" >36.7784</td>
#       <td id="T_8d222_row1_col2" class="data row1 col2" >6.0645</td>
#       <td id="T_8d222_row1_col3" class="data row1 col3" >0.1250</td>
#       <td id="T_8d222_row1_col4" class="data row1 col4" >0.3473</td>
#       <td id="T_8d222_row1_col5" class="data row1 col5" >0.3143</td>
#     </tr>
#     <tr>
#       <th id="T_8d222_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8d222_row2_col0" class="data row2 col0" >3.5415</td>
#       <td id="T_8d222_row2_col1" class="data row2 col1" >21.7125</td>
#       <td id="T_8d222_row2_col2" class="data row2 col2" >4.6597</td>
#       <td id="T_8d222_row2_col3" class="data row2 col3" >0.4968</td>
#       <td id="T_8d222_row2_col4" class="data row2 col4" >0.2777</td>
#       <td id="T_8d222_row2_col5" class="data row2 col5" >0.2503</td>
#     </tr>
#     <tr>
#       <th id="T_8d222_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8d222_row3_col0" class="data row3 col0" >3.9403</td>
#       <td id="T_8d222_row3_col1" class="data row3 col1" >30.9839</td>
#       <td id="T_8d222_row3_col2" class="data row3 col2" >5.5663</td>
#       <td id="T_8d222_row3_col3" class="data row3 col3" >0.1876</td>
#       <td id="T_8d222_row3_col4" class="data row3 col4" >0.2096</td>
#       <td id="T_8d222_row3_col5" class="data row3 col5" >0.1602</td>
#     </tr>
#     <tr>
#       <th id="T_8d222_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8d222_row4_col0" class="data row4 col0" >5.4915</td>
#       <td id="T_8d222_row4_col1" class="data row4 col1" >49.2293</td>
#       <td id="T_8d222_row4_col2" class="data row4 col2" >7.0164</td>
#       <td id="T_8d222_row4_col3" class="data row4 col3" >0.2587</td>
#       <td id="T_8d222_row4_col4" class="data row4 col4" >0.2782</td>
#       <td id="T_8d222_row4_col5" class="data row4 col5" >0.2375</td>
#     </tr>
#     <tr>
#       <th id="T_8d222_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8d222_row5_col0" class="data row5 col0" >5.4682</td>
#       <td id="T_8d222_row5_col1" class="data row5 col1" >45.2198</td>
#       <td id="T_8d222_row5_col2" class="data row5 col2" >6.7246</td>
#       <td id="T_8d222_row5_col3" class="data row5 col3" >0.1671</td>
#       <td id="T_8d222_row5_col4" class="data row5 col4" >0.2299</td>
#       <td id="T_8d222_row5_col5" class="data row5 col5" >0.1996</td>
#     </tr>
#     <tr>
#       <th id="T_8d222_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8d222_row6_col0" class="data row6 col0" >5.8974</td>
#       <td id="T_8d222_row6_col1" class="data row6 col1" >52.2190</td>
#       <td id="T_8d222_row6_col2" class="data row6 col2" >7.2263</td>
#       <td id="T_8d222_row6_col3" class="data row6 col3" >0.4533</td>
#       <td id="T_8d222_row6_col4" class="data row6 col4" >0.2898</td>
#       <td id="T_8d222_row6_col5" class="data row6 col5" >0.2849</td>
#     </tr>
#     <tr>
#       <th id="T_8d222_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8d222_row7_col0" class="data row7 col0" >8.5975</td>
#       <td id="T_8d222_row7_col1" class="data row7 col1" >133.1550</td>
#       <td id="T_8d222_row7_col2" class="data row7 col2" >11.5393</td>
#       <td id="T_8d222_row7_col3" class="data row7 col3" >0.4048</td>
#       <td id="T_8d222_row7_col4" class="data row7 col4" >0.3473</td>
#       <td id="T_8d222_row7_col5" class="data row7 col5" >0.2792</td>
#     </tr>
#     <tr>
#       <th id="T_8d222_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8d222_row8_col0" class="data row8 col0" >5.2758</td>
#       <td id="T_8d222_row8_col1" class="data row8 col1" >40.4567</td>
#       <td id="T_8d222_row8_col2" class="data row8 col2" >6.3606</td>
#       <td id="T_8d222_row8_col3" class="data row8 col3" >0.5614</td>
#       <td id="T_8d222_row8_col4" class="data row8 col4" >0.3257</td>
#       <td id="T_8d222_row8_col5" class="data row8 col5" >0.3145</td>
#     </tr>
#     <tr>
#       <th id="T_8d222_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8d222_row9_col0" class="data row9 col0" >5.3402</td>
#       <td id="T_8d222_row9_col1" class="data row9 col1" >47.1461</td>
#       <td id="T_8d222_row9_col2" class="data row9 col2" >6.8663</td>
#       <td id="T_8d222_row9_col3" class="data row9 col3" >-0.2674</td>
#       <td id="T_8d222_row9_col4" class="data row9 col4" >0.3867</td>
#       <td id="T_8d222_row9_col5" class="data row9 col5" >0.3458</td>
#     </tr>
#     <tr>
#       <th id="T_8d222_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8d222_row10_col0" class="data row10 col0" >5.3303</td>
#       <td id="T_8d222_row10_col1" class="data row10 col1" >42.9562</td>
#       <td id="T_8d222_row10_col2" class="data row10 col2" >6.5541</td>
#       <td id="T_8d222_row10_col3" class="data row10 col3" >0.0115</td>
#       <td id="T_8d222_row10_col4" class="data row10 col4" >0.5188</td>
#       <td id="T_8d222_row10_col5" class="data row10 col5" >0.5589</td>
#     </tr>
#     <tr>
#       <th id="T_8d222_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8d222_row11_col0" class="data row11 col0" >6.2116</td>
#       <td id="T_8d222_row11_col1" class="data row11 col1" >63.8155</td>
#       <td id="T_8d222_row11_col2" class="data row11 col2" >7.9885</td>
#       <td id="T_8d222_row11_col3" class="data row11 col3" >0.4895</td>
#       <td id="T_8d222_row11_col4" class="data row11 col4" >0.3950</td>
#       <td id="T_8d222_row11_col5" class="data row11 col5" >0.3251</td>
#     </tr>
#     <tr>
#       <th id="T_8d222_level0_row12" class="row_heading level0 row12" >Mean</th>
#       <td id="T_8d222_row12_col0" class="data row12 col0" >5.6384</td>
#       <td id="T_8d222_row12_col1" class="data row12 col1" >56.1159</td>
#       <td id="T_8d222_row12_col2" class="data row12 col2" >7.2534</td>
#       <td id="T_8d222_row12_col3" class="data row12 col3" >0.2816</td>
#       <td id="T_8d222_row12_col4" class="data row12 col4" >0.3321</td>
#       <td id="T_8d222_row12_col5" class="data row12 col5" >0.2966</td>
#     </tr>
#     <tr>
#       <th id="T_8d222_level0_row13" class="row_heading level0 row13" >Std</th>
#       <td id="T_8d222_row13_col0" class="data row13 col0" >1.3346</td>
#       <td id="T_8d222_row13_col1" class="data row13 col1" >31.2741</td>
#       <td id="T_8d
# Fitting 12 folds for each of 10 candidates, totalling 120 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
model_2 = exp1.create_model('huber')
# Out:
# <style type="text/css">
# #T_a56c2_row12_col0, #T_a56c2_row12_col1, #T_a56c2_row12_col2, #T_a56c2_row12_col3, #T_a56c2_row12_col4, #T_a56c2_row12_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a56c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a56c2_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a56c2_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a56c2_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a56c2_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a56c2_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a56c2_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a56c2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a56c2_row0_col0" class="data row0 col0" >7.6843</td>
#       <td id="T_a56c2_row0_col1" class="data row0 col1" >112.6044</td>
#       <td id="T_a56c2_row0_col2" class="data row0 col2" >10.6115</td>
#       <td id="T_a56c2_row0_col3" class="data row0 col3" >0.4777</td>
#       <td id="T_a56c2_row0_col4" class="data row0 col4" >0.3763</td>
#       <td id="T_a56c2_row0_col5" class="data row0 col5" >0.2885</td>
#     </tr>
#     <tr>
#       <th id="T_a56c2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a56c2_row1_col0" class="data row1 col0" >4.9519</td>
#       <td id="T_a56c2_row1_col1" class="data row1 col1" >37.1379</td>
#       <td id="T_a56c2_row1_col2" class="data row1 col2" >6.0941</td>
#       <td id="T_a56c2_row1_col3" class="data row1 col3" >0.1165</td>
#       <td id="T_a56c2_row1_col4" class="data row1 col4" >0.3487</td>
#       <td id="T_a56c2_row1_col5" class="data row1 col5" >0.3191</td>
#     </tr>
#     <tr>
#       <th id="T_a56c2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a56c2_row2_col0" class="data row2 col0" >3.4852</td>
#       <td id="T_a56c2_row2_col1" class="data row2 col1" >21.5901</td>
#       <td id="T_a56c2_row2_col2" class="data row2 col2" >4.6465</td>
#       <td id="T_a56c2_row2_col3" class="data row2 col3" >0.4996</td>
#       <td id="T_a56c2_row2_col4" class="data row2 col4" >0.2819</td>
#       <td id="T_a56c2_row2_col5" class="data row2 col5" >0.2548</td>
#     </tr>
#     <tr>
#       <th id="T_a56c2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a56c2_row3_col0" class="data row3 col0" >3.9917</td>
#       <td id="T_a56c2_row3_col1" class="data row3 col1" >31.9216</td>
#       <td id="T_a56c2_row3_col2" class="data row3 col2" >5.6499</td>
#       <td id="T_a56c2_row3_col3" class="data row3 col3" >0.1630</td>
#       <td id="T_a56c2_row3_col4" class="data row3 col4" >0.2131</td>
#       <td id="T_a56c2_row3_col5" class="data row3 col5" >0.1613</td>
#     </tr>
#     <tr>
#       <th id="T_a56c2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a56c2_row4_col0" class="data row4 col0" >5.5528</td>
#       <td id="T_a56c2_row4_col1" class="data row4 col1" >49.7784</td>
#       <td id="T_a56c2_row4_col2" class="data row4 col2" >7.0554</td>
#       <td id="T_a56c2_row4_col3" class="data row4 col3" >0.2504</td>
#       <td id="T_a56c2_row4_col4" class="data row4 col4" >0.2792</td>
#       <td id="T_a56c2_row4_col5" class="data row4 col5" >0.2400</td>
#     </tr>
#     <tr>
#       <th id="T_a56c2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a56c2_row5_col0" class="data row5 col0" >5.3226</td>
#       <td id="T_a56c2_row5_col1" class="data row5 col1" >42.4838</td>
#       <td id="T_a56c2_row5_col2" class="data row5 col2" >6.5180</td>
#       <td id="T_a56c2_row5_col3" class="data row5 col3" >0.2175</td>
#       <td id="T_a56c2_row5_col4" class="data row5 col4" >0.2237</td>
#       <td id="T_a56c2_row5_col5" class="data row5 col5" >0.1933</td>
#     </tr>
#     <tr>
#       <th id="T_a56c2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a56c2_row6_col0" class="data row6 col0" >5.8314</td>
#       <td id="T_a56c2_row6_col1" class="data row6 col1" >51.4869</td>
#       <td id="T_a56c2_row6_col2" class="data row6 col2" >7.1754</td>
#       <td id="T_a56c2_row6_col3" class="data row6 col3" >0.4609</td>
#       <td id="T_a56c2_row6_col4" class="data row6 col4" >0.2880</td>
#       <td id="T_a56c2_row6_col5" class="data row6 col5" >0.2825</td>
#     </tr>
#     <tr>
#       <th id="T_a56c2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a56c2_row7_col0" class="data row7 col0" >8.6670</td>
#       <td id="T_a56c2_row7_col1" class="data row7 col1" >137.6620</td>
#       <td id="T_a56c2_row7_col2" class="data row7 col2" >11.7329</td>
#       <td id="T_a56c2_row7_col3" class="data row7 col3" >0.3847</td>
#       <td id="T_a56c2_row7_col4" class="data row7 col4" >0.3556</td>
#       <td id="T_a56c2_row7_col5" class="data row7 col5" >0.2847</td>
#     </tr>
#     <tr>
#       <th id="T_a56c2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a56c2_row8_col0" class="data row8 col0" >5.2943</td>
#       <td id="T_a56c2_row8_col1" class="data row8 col1" >40.2835</td>
#       <td id="T_a56c2_row8_col2" class="data row8 col2" >6.3469</td>
#       <td id="T_a56c2_row8_col3" class="data row8 col3" >0.5633</td>
#       <td id="T_a56c2_row8_col4" class="data row8 col4" >0.3277</td>
#       <td id="T_a56c2_row8_col5" class="data row8 col5" >0.3120</td>
#     </tr>
#     <tr>
#       <th id="T_a56c2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a56c2_row9_col0" class="data row9 col0" >5.3238</td>
#       <td id="T_a56c2_row9_col1" class="data row9 col1" >46.8528</td>
#       <td id="T_a56c2_row9_col2" class="data row9 col2" >6.8449</td>
#       <td id="T_a56c2_row9_col3" class="data row9 col3" >-0.2595</td>
#       <td id="T_a56c2_row9_col4" class="data row9 col4" >0.3845</td>
#       <td id="T_a56c2_row9_col5" class="data row9 col5" >0.3458</td>
#     </tr>
#     <tr>
#       <th id="T_a56c2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a56c2_row10_col0" class="data row10 col0" >5.0258</td>
#       <td id="T_a56c2_row10_col1" class="data row10 col1" >41.2149</td>
#       <td id="T_a56c2_row10_col2" class="data row10 col2" >6.4199</td>
#       <td id="T_a56c2_row10_col3" class="data row10 col3" >0.0516</td>
#       <td id="T_a56c2_row10_col4" class="data row10 col4" >0.5061</td>
#       <td id="T_a56c2_row10_col5" class="data row10 col5" >0.5147</td>
#     </tr>
#     <tr>
#       <th id="T_a56c2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a56c2_row11_col0" class="data row11 col0" >6.2260</td>
#       <td id="T_a56c2_row11_col1" class="data row11 col1" >63.9678</td>
#       <td id="T_a56c2_row11_col2" class="data row11 col2" >7.9980</td>
#       <td id="T_a56c2_row11_col3" class="data row11 col3" >0.4882</td>
#       <td id="T_a56c2_row11_col4" class="data row11 col4" >0.3919</td>
#       <td id="T_a56c2_row11_col5" class="data row11 col5" >0.3242</td>
#     </tr>
#     <tr>
#       <th id="T_a56c2_level0_row12" class="row_heading level0 row12" >Mean</th>
#       <td id="T_a56c2_row12_col0" class="data row12 col0" >5.6131</td>
#       <td id="T_a56c2_row12_col1" class="data row12 col1" >56.4153</td>
#       <td id="T_a56c2_row12_col2" class="data row12 col2" >7.2578</td>
#       <td id="T_a56c2_row12_col3" class="data row12 col3" >0.2845</td>
#       <td id="T_a56c2_row12_col4" class="data row12 col4" >0.3314</td>
#       <td id="T_a56c2_row12_col5" class="data row12 col5" >0.2934</td>
#     </tr>
#     <tr>
#       <th id="T_a56c2_level0_row13" class="row_heading level0 row13" >Std</th>
#       <td id="T_a56c2_row13_col0" class="data row13 col0" >1.3617</td>
#       <td id="T_a56c2_row13_col1" class="data row13 col1" >32.7170</td>
#       <td id="T_a5

# %%
blend = exp1.blend_models([model_1, model_2])
# Out:
# <style type="text/css">
# #T_c9308_row12_col0, #T_c9308_row12_col1, #T_c9308_row12_col2, #T_c9308_row12_col3, #T_c9308_row12_col4, #T_c9308_row12_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c9308">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9308_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c9308_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c9308_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c9308_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c9308_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c9308_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9308_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9308_row0_col0" class="data row0 col0" >7.6843</td>
#       <td id="T_c9308_row0_col1" class="data row0 col1" >112.6044</td>
#       <td id="T_c9308_row0_col2" class="data row0 col2" >10.6115</td>
#       <td id="T_c9308_row0_col3" class="data row0 col3" >0.4777</td>
#       <td id="T_c9308_row0_col4" class="data row0 col4" >0.3763</td>
#       <td id="T_c9308_row0_col5" class="data row0 col5" >0.2885</td>
#     </tr>
#     <tr>
#       <th id="T_c9308_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_
level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c9308_row8_col0" class="data row8 col0" >5.2943</td>
#       <td id="T_c9308_row8_col1" class="data row8 col1" >40.2835</td>
#       <td id="T_c9308_row8_col2" class="data row8 col2" >6.3469</td>
#       <td id="T_c9308_row8_col3" class="data row8 col3" >0.5633</td>
#       <td id="T_c9308_row8_col4" class="data row8 col4" >0.3277</td>
#       <td id="T_c9308_row8_col5" class="data row8 col5" >0.3120</td>
#     </tr>
#     <tr>
#       <th id="T_c9308_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c9308_row9_col0" class="data row9 col0" >5.3238</td>
#       <td id="T_c9308_row9_col1" class="data row9 col1" >46.8528</td>
#       <td id="T_c9308_row9_col2" class="data row9 col2" >6.8449</td>
#       <td id="T_c9308_row9_col3" class="data row9 col3" >-0.2595</td>
#       <td id="T_c9308_row9_col4" class="data row9 col4" >0.3845</td>
#       <td id="T_c9308_row9_col5" class="data row9 col5" >0.3458</td>
#     </tr>
#     <tr>
#       <th id="T_c9308_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c9308_row10_col0" class="data row10 col0" >5.0258</td>
#       <td id="T_c9308_row10_col1" class="data row10 col1" >41.2149</td>
#       <td id="T_c9308_row10_col2" class="data row10 col2" >6.4199</td>
#       <td id="T_c9308_row10_col3" class="data row10 col3" >0.0516</td>
#       <td id="T_c9308_row10_col4" class="data row10 col4" >0.5061</td>
#       <td id="T_c9308_row10_col5" class="data row10 col5" >0.5147</td>
#     </tr>
#     <tr>
#       <th id="T_c9308_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c9308_row11_col0" class="data row11 col0" >6.2260</td>
#       <td id="T_c9308_row11_col1" class="data row11 col1" >63.9678</td>
#       <td id="T_c9308_row11_col2" class="data row11 col2" >7.9980</td>
#       <td id="T_c9308_row11_col3" class="data row11 col3" >0.4882</td>
#       <td id="T_c9308_row11_col4" class="data row11 col4" >0.3919</td>
#       <td id="T_c9308_row11_col5" class="data row11 col5" >0.3242</td>
#     </tr>
#     <tr>
#       <th id="T_c9308_level0_row12" class="row_heading level0 row12" >Mean</th>
#       <td id="T_c9308_row12_col0" class="data row12 col0" >5.6131</td>
#       <td id="T_c9308_row12_col1" class="data row12 col1" >56.4153</td>
#       <td id="T_c9308_row12_col2" class="data row12 col2" >7.2578</td>
#       <td id="T_c9308_row12_col3" class="data row12 col3" >0.2845</td>
#       <td id="T_c9308_row12_col4" class="data row12 col4" >0.3314</td>
#       <td id="T_c9308_row12_col5" class="data row12 col5" >0.2934</td>
#     </tr>
#     <tr>
#       <th id="T_c9308_level0_row13" class="row_heading level0 row13" >Std</th>
#       <td id="T_c9308_row13_col0" class="data row13 col0" >1.3617</td>
#       <td id="T_c9308_row13_col1" class="data row13 col1" >32.7170</td>
#       <td id="T_c9

# %%
tune = exp1.tune_model(blend)
# Out:
# <style type="text/css">
# #T_e50f2_row12_col0, #T_e50f2_row12_col1, #T_e50f2_row12_col2, #T_e50f2_row12_col3, #T_e50f2_row12_col4, #T_e50f2_row12_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_e50f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e50f2_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_e50f2_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_e50f2_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_e50f2_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_e50f2_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_e50f2_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e50f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_
_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e50f2_row6_col0" class="data row6 col0" >5.8314</td>
#       <td id="T_e50f2_row6_col1" class="data row6 col1" >51.4869</td>
#       <td id="T_e50f2_row6_col2" class="data row6 col2" >7.1754</td>
#       <td id="T_e50f2_row6_col3" class="data row6 col3" >0.4609</td>
#       <td id="T_e50f2_row6_col4" class="data row6 col4" >0.2880</td>
#       <td id="T_e50f2_row6_col5" class="data row6 col5" >0.2825</td>
#     </tr>
#     <tr>
#       <th id="T_e50f2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e50f2_row7_col0" class="data row7 col0" >8.6670</td>
#       <td id="T_e50f2_row7_col1" class="data row7 col1" >137.6620</td>
#       <td id="T_e50f2_row7_col2" class="data row7 col2" >11.7329</td>
#       <td id="T_e50f2_row7_col3" class="data row7 col3" >0.3847</td>
#       <td id="T_e50f2_row7_col4" class="data row7 col4" >0.3556</td>
#       <td id="T_e50f2_row7_col5" class="data row7 col5" >0.2847</td>
#     </tr>
#     <tr>
#       <th id="T_e50f2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e50f2_row8_col0" class="data row8 col0" >5.2943</td>
#       <td id="T_e50f2_row8_col1" class="data row8 col1" >40.2835</td>
#       <td id="T_e50f2_row8_col2" class="data row8 col2" >6.3469</td>
#       <td id="T_e50f2_row8_col3" class="data row8 col3" >0.5633</td>
#       <td id="T_e50f2_row8_col4" class="data row8 col4" >0.3277</td>
#       <td id="T_e50f2_row8_col5" class="data row8 col5" >0.3120</td>
#     </tr>
#     <tr>
#       <th id="T_e50f2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e50f2_row9_col0" class="data row9 col0" >5.3238</td>
#       <td id="T_e50f2_row9_col1" class="data row9 col1" >46.8528</td>
#       <td id="T_e50f2_row9_col2" class="data row9 col2" >6.8449</td>
#       <td id="T_e50f2_row9_col3" class="data row9 col3" >-0.2595</td>
#       <td id="T_e50f2_row9_col4" class="data row9 col4" >0.3845</td>
#       <td id="T_e50f2_row9_col5" class="data row9 col5" >0.3458</td>
#     </tr>
#     <tr>
#       <th id="T_e50f2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e50f2_row10_col0" class="data row10 col0" >5.0258</td>
#       <td id="T_e50f2_row10_col1" class="data row10 col1" >41.2149</td>
#       <td id="T_e50f2_row10_col2" class="data row10 col2" >6.4199</td>
#       <td id="T_e50f2_row10_col3" class="data row10 col3" >0.0516</td>
#       <td id="T_e50f2_row10_col4" class="data row10 col4" >0.5061</td>
#       <td id="T_e50f2_row10_col5" class="data row10 col5" >0.5147</td>
#     </tr>
#     <tr>
#       <th id="T_e50f2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e50f2_row11_col0" class="data row11 col0" >6.2260</td>
#       <td id="T_e50f2_row11_col1" class="data row11 col1" >63.9678</td>
#       <td id="T_e50f2_row11_col2" class="data row11 col2" >7.9980</td>
#       <td id="T_e50f2_row11_col3" class="data row11 col3" >0.4882</td>
#       <td id="T_e50f2_row11_col4" class="data row11 col4" >0.3919</td>
#       <td id="T_e50f2_row11_col5" class="data row11 col5" >0.3242</td>
#     </tr>
#     <tr>
#       <th id="T_e50f2_level0_row12" class="row_heading level0 row12" >Mean</th>
#       <td id="T_e50f2_row12_col0" class="data row12 col0" >5.6131</td>
#       <td id="T_e50f2_row12_col1" class="data row12 col1" >56.4153</td>
#       <td id="T_e50f2_row12_col2" class="data row12 col2" >7.2578</td>
#       <td id="T_e50f2_row12_col3" class="data row12 col3" >0.2845</td>
#       <td id="T_e50f2_row12_col4" class="data row12 col4" >0.3314</td>
#       <td id="T_e50f2_row12_col5" class="data row12 col5" >0.2934</td>
#     </tr>
#     <tr>
#       <th id="T_e50f2_level0_row13" class="row_heading level0 row13" >Std</th>
#       <td id="T_e50f2_row13_col0" class="data row13 col0" >1.3617</td>
#       <td id="T_e50f2_row13_col1" class="data row13 col1" >32.7170</td>
#       <td id="T_e5
# Fitting 12 folds for each of 10 candidates, totalling 120 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
new_data = test_data.copy().drop(['pm_10'], axis=1)
predictions = exp1.predict_model(tune, data=new_data)
predictions.head()
# Out:
#                       humidity  temperature  year  month  day  day_of_week  \
# timestamp
# 2025-01-13 07:00:00  78.292206    25.997341  2025      1   13            0
#
#                      week_of_year  season  dew_point  is_weekend  ...  \
# timestamp                                                         ...
# 2025-01-13 07:00:00             3       2  21.655781           0  ...
#
#                      temperature_rolling_5  temperature_rolling_7  \
# timestamp
# 2025-01-13 07:00:00               28.00857              28.287636
#
#                      temperature_lag_1 temperature_lag_2  temperature_lag_3  \
# timestamp
# 2025-01-13 07:00:00          25.434973          28.35746          28.945705
#
#                      temperature_lag_5  temperature_lag_7  temp_diff  \
# timestamp
# 2025-01-13 07:00:00          28.921543          28.825508   0.562369
#
#                      humidity_diff  prediction_label
# timestamp
# 2025-01-13 07:00:00      -7.087604         29.660744
#
# [1 rows x 49 columns]

# %%
predict_v = predictions['prediction_label']
predict_v.head(7)
# Out:
# timestamp
# 2025-01-13 07:00:00    29.660744
# Freq: D, Name: prediction_label, dtype: float64

# %%
real = test_data['pm_10']
real.head(7)
# Out:
# timestamp
# 2025-01-13 07:00:00    48.632215
# Freq: D, Name: pm_10, dtype: float64

# %%
# สมมุติว่า result คือ DataFrame ที่รวม predictions กับ pm_10
result = pd.concat([predict_v, test_data['pm_10']], axis=1)
result.columns = ['Predictions', 'Actual PM10']  # ตั้งชื่อคอลัมน์

# %% [markdown]
# # ทำนาย 1 วันข้างหน้า ต้องทำนายเผื่อ 2 วัน

# %%
import pandas as pd
import matplotlib.pyplot as plt

# สมมุติว่า result คือ DataFrame ที่รวม predictions กับ pm_10
result = pd.concat([predict_v, test_data['pm_10']], axis=1)
result.columns = ['Predictions', 'Actual PM10']  # ตั้งชื่อคอลัมน์

# พล็อตข้อมูล
result.plot(figsize=(10, 6))

# ตั้งชื่อกราฟ
plt.title('Predictions vs Actual PM10')
plt.xlabel('Index')
plt.ylabel('PM10 Values')

# แสดงกราฟ
plt.show()

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_percentage_error, r2_score

# สร้าง result จากการ shift ค่าทำนาย
result = pd.concat([predict_v.shift(-1), test_data['pm_10']], axis=1)
result.columns = ['predicted', 'actual']

# ลบแถวที่มีค่า NaN
result = result.dropna()

# คำนวณ MAPE
mape = mean_absolute_percentage_error(result['actual'], result['predicted']) * 100

# คำนวณ R2
r2 = r2_score(result['actual'], result['predicted'])

print(f'MAPE: {mape}%')
print(f'R²: {r2}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 12
#       9 result = result.dropna()
#      11 # คำนวณ MAPE
# ---> 12 mape = mean_absolute_percentage_error(result['actual'], result['predicted']) * 100
#      14 # คำนวณ R2
#      15 r2 = r2_score(result['actual'], result['predicted'])
#
# File d:\Normal File\Coder\MINI_PROJECT_1-2\pycaret_venv\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File d:\Normal File\Coder\MINI_PROJECT_1-2\pycaret_venv\Lib\site-packages\sklearn\metrics\_regression.py:390, in mean_absolute_percentage_error(y_true, y_pred, sample_weight, multioutput)
#     312 @validate_params(
#     313     {
#     314         "y_true": ["array-like"],
#    (...)
#     322     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average"
#     323 ):
#     324     """Mean absolute percentage error (MAPE) regression loss.
#     325
#     326     Note here that the output is not a percentage in the range [0, 100]
#    (...)
#     388     112589990684262.48
#     389     """
# --> 390     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     391         y_true, y_pred, multioutput
#     392     )
#     393     check_consistent_length(y_true, y_pred, sample_weight)
#     394     epsilon = np.finfo(np.float64).eps
#
# File d:\Normal File\Coder\MINI_PROJECT_1-2\pycaret_venv\Lib\site-packages\sklearn\metrics\_regression.py:103, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      69 """Check that y_true and y_pred belong to the same regression task.
#      70
#      71 Parameters
#    (...)
#     100     correct keyword.
#     101 """
#     102 check_consistent_length(y_true, y_pred)
# --> 103 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     104 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     106 if y_true.ndim == 1:
#
# File d:\Normal File\Coder\MINI_PROJECT_1-2\pycaret_venv\Lib\site-packages\sklearn\utils\validation.py:1072, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1070     n_samples = _num_samples(array)
#    1071     if n_samples < ensure_min_samples:
# -> 1072         raise ValueError(
#    1073             "Found array with %d sample(s) (shape=%s) while a"
#    1074             " minimum of %d is required%s."
#    1075             % (n_samples, array.shape, ensure_min_samples, context)
#    1076         )
#    1078 if ensure_min_features > 0 and array.ndim == 2:
#    1079     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %%
from itertools import combinations

best_list = list(best)
# เก็บชื่อโมเดลและอ็อบเจกต์ไว้ใน dict
model_names = {model.__class__.__name__: model for model in best_list}

# Dictionary เก็บค่า MAPE
mape_results = {}

loop = 1
# วนลูปเลือกโมเดลทีละคู่
for model1_name, model2_name in combinations(model_names.keys(), 2):
    print(f"{loop} --> Blending: {model1_name} + {model2_name}")  # แสดงว่ากำลังประมวลผลคู่ไหน

    # นำโมเดลทั้งสองมาผสมกัน
    blended_model = exp1.blend_models([model_names[model1_name], model_names[model2_name]], verbose=False)
    
    # ดึงค่าประเมินผลล่าสุด
    result = exp1.pull()
    # ตรวจสอบว่ามีคอลัมน์ 'MAPE' หรือไม่
    if 'MAPE' in result.columns and 'Mean' in result.index:
        mape_value = result.loc['Mean', 'MAPE']
    elif 'R2' in result.columns and 'Mean' in result.index:
        mape_value = result.loc['Mean', 'R2']
    else:
        print(f"❌ ไม่มีค่าที่ต้องการสำหรับ {model1_name} + {model2_name}")
        continue  # ข้ามรอบนี้ถ้าไม่มีค่า MAPE หรือ R2

    # บันทึกค่าลง dictionary
    mape_results[f"{model1_name}, {model2_name}"] = mape_value

    print('-'* 60)
    loop += 1
# Out:
# 1 --> Blending: Lasso + OrthogonalMatchingPursuit
# ------------------------------------------------------------
# 2 --> Blending: Lasso + LassoLars
# ------------------------------------------------------------
# 3 --> Blending: Lasso + ElasticNet
# ------------------------------------------------------------
# 4 --> Blending: Lasso + BayesianRidge
# ------------------------------------------------------------
# 5 --> Blending: Lasso + HuberRegressor
# ------------------------------------------------------------
# 6 --> Blending: Lasso + Ridge
# ------------------------------------------------------------
# 7 --> Blending: Lasso + RandomForestRegressor
# ------------------------------------------------------------
# 8 --> Blending: Lasso + ExtraTreesRegressor
# ------------------------------------------------------------
# 9 --> Blending: Lasso + GradientBoostingRegressor
# ------------------------------------------------------------
# 10 --> Blending: Lasso + AdaBoostRegressor
# ------------------------------------------------------------
# 11 --> Blending: Lasso + LGBMRegressor
# ------------------------------------------------------------
# 12 --> Blending: Lasso + KNeighborsRegressor
# ------------------------------------------------------------
# 13 --> Blending: Lasso + PassiveAggressiveRegressor
# ------------------------------------------------------------
# 14 --> Blending: Lasso + DecisionTreeRegressor
# ------------------------------------------------------------
# 15 --> Blending: Lasso + DummyRegressor
# ------------------------------------------------------------
# 16 --> Blending: Lasso + LinearRegression
# ------------------------------------------------------------
# 17 --> Blending: OrthogonalMatchingPursuit + LassoLars
# ------------------------------------------------------------
# 18 --> Blending: OrthogonalMatchingPursuit + ElasticNet
# ------------------------------------------------------------
# 19 --> Blending: OrthogonalMatchingPursuit + BayesianRidge
# ------------------------------------------------------------
# 20 --> Blending: OrthogonalMatchingPursuit + HuberRegressor
# ------------------------------------------------------------
# 21 --> Blending: OrthogonalMatchingPursuit + Ridge
# ------------------------------------------------------------
# 22 --> Blending: OrthogonalMatchingPursuit + RandomForestRegressor
# ------------------------------------------------------------
# 23 --> Blending: OrthogonalMatchingPursuit + ExtraTreesRegressor
# ------------------------------------------------------------
# 24 --> Blending: OrthogonalMatchingPursuit + GradientBoostingRegressor
# ------------------------------------------------------------
# 25 --> Blending: OrthogonalMatchingPursuit + AdaBoostRegressor
# ------------------------------------------------------------
# 26 --> Blending: OrthogonalMatchingPursuit + LGBMRegressor
# ------------------------------------------------------------
# 27 --> Blending: OrthogonalMatchingPursuit + KNeighborsRegressor
# ------------------------------------------------------------
# 28 --> Blending: OrthogonalMatchingPursuit + PassiveAggressiveRegressor
# ------------------------------------------------------------
# 29 --> Blending: OrthogonalMatchingPursuit + DecisionTreeRegressor
# ------------------------------------------------------------
# 30 --> Blending: OrthogonalMatchingPursuit + DummyRegressor
# ------------------------------------------------------------
# 31 --> Blending: OrthogonalMatchingPursuit + LinearRegression
# ------------------------------------------------------------
# 32 --> Blending: LassoLars + ElasticNet
# ------------------------------------------------------------
# 33 --> Blending: LassoLars + BayesianRidge
# ------------------------------------------------------------
# 34 --> Blending: LassoLars + HuberRegressor
# ------------------------------------------------------------
# 35 --> Blending: LassoLars + Ridge
# ------------------------------------------------------------
# 36 --> Blending: LassoLars + RandomForestRegressor
# ------------------------------------------------------------
# 37 --> Blending: LassoLars + ExtraTreesRegressor
# ------------------------------------------------------------
# 38 --> Blending: LassoLars + GradientBoostingRegressor
# ------------------------------------------------------------
# 39 --> Blending: LassoLars + AdaBoostRegressor
# ------------------------------------------------------------
# 40 --> Blending: LassoLars + LGBMRegressor
# ------------------------------------------------------------
# 41 --> Blending: LassoLars + KNeighborsRegressor
# ------------------------------------------------------------
# 42 --> Blending: LassoLars + PassiveAggressiveRegressor
# ------------------------------------------------------------
# 43 --> Blending: LassoLars + DecisionTreeRegressor
# ------------------------------------------------------------
# 44 --> Blending: LassoLars + DummyRegressor
# ------------------------------------------------------------
# 45 --> Blending: LassoLars + LinearRegression
# ------------------------------------------------------------
# 46 --> Blending: ElasticNet + BayesianRidge
# ------------------------------------------------------------
# 47 --> Blending: ElasticNet + HuberRegressor
# ------------------------------------------------------------
# 48 --> Blending: ElasticNet + Ridge
# ------------------------------------------------------------
# 49 --> Blending: ElasticNet + RandomForestRegressor
# ------------------------------------------------------------
# 50 --> Blending: ElasticNet + ExtraTreesRegressor
# ------------------------------------------------------------
# 51 --> Blending: ElasticNet + GradientBoostingRegressor
# ------------------------------------------------------------
# 52 --> Blending: ElasticNet + AdaBoostRegressor
# ------------------------------------------------------------
# 53 --> Blending: ElasticNet + LGBMRegressor
# ------------------------------------------------------------
# 54 --> Blending: ElasticNet + KNeighborsRegressor
# ------------------------------------------------------------
# 55 --> Blending: ElasticNet + PassiveAggressiveRegressor
# ------------------------------------------------------------
# 56 --> Blending: ElasticNet + DecisionTreeRegressor
# ------------------------------------------------------------
# 57 --> Blending: ElasticNet + DummyRegressor
# ------------------------------------------------------------
# 58 --> Blending: ElasticNet + LinearRegression
# ------------------------------------------------------------
# 59 --> Blending: BayesianRidge + HuberRegressor
# ------------------------------------------------------------
# 60 --> Blending: BayesianRidge + Ridge
# ------------------------------------------------------------
# 61 --> Blending: BayesianRidge + RandomForestRegressor
# ------------------------------------------------------------
# 62 --> Blending: BayesianRidge + ExtraTreesRegressor
# ------------------------------------------------------------
# 63 --> Blending: BayesianRidge + GradientBoostingRegressor
# ------------------------------------------------------------
# 64 --> Blending: BayesianRidge + AdaBoostRegressor
# ------------------------------------------------------------
# 65 --> Blending: BayesianRidge + LGBMRegressor
# ------------------------------------------------------------
# 66 --> Blending: BayesianRidge + KNeighborsRegressor
# ------------------------------------------------------------
# 67 --> Blending: BayesianRidge + PassiveAggressiveRegressor
# ------------------------------------------------------------
# 68 --> Blending: BayesianRidge + DecisionTreeRegressor
# ------------------------------------------------------------
# 69 --> Blending: BayesianRidge + DummyRegressor
# ------------------------------------------------------------
# 70 --> Blending: BayesianRidge + LinearRegression
# ------------------------------------------------------------
# 71 --> Blending: HuberRegressor + Ridge
# ------------------------------------------------------------
# 72 --> Blending: HuberRegressor + RandomForestRegressor
# ------------------------------------------------------------
# 73 --> Blending: HuberRegressor + ExtraTreesRegressor
# ------------------------------------------------------------
# 74 --> Blending: HuberRegressor + GradientBoostingRegressor
# ------------------------------------------------------------
# 75 --> Blending: HuberRegressor + AdaBoostRegressor
# ------------------------------------------------------------
# 76 --> Blending: HuberRegressor + LGBMRegressor
# ------------------------------------------------------------
# 77 --> Blending: HuberRegressor + KNeighborsRegressor
# ------------------------------------------------------------
# 78 --> Blending: HuberRegressor + PassiveAggressiveRegressor
# ------------------------------------------------------------
# 79 --> Blending: HuberRegressor + DecisionTreeRegressor
# ------------------------------------------------------------
# 80 --> Blending: HuberRegressor + DummyRegressor
# ------------------------------------------------------------
# 81 --> Blending: HuberRegressor + LinearRegression
# ------------------------------------------------------------
# 82 --> Blending: Ridge + RandomForestRegressor
# ------------------------------------------------------------
# 83 --> Blending: Ridge + ExtraTreesRegressor
# ------------------------------------------------------------
# 84 --> Blending: Ridge + GradientBoostingRegressor
# ------------------------------------------------------------
# 85 --> Blending: Ridge + AdaBoostRegressor
# ------------------------------------------------------------
# 86 --> Blending: Ridge + LGBMRegressor
# ------------------------------------------------------------
# 87 --> Blending: Ridge + KNeighborsRegressor
# ------------------------------------------------------------
# 88 --> Blending: Ridge + PassiveAggressiveRegressor
# ------------------------------------------------------------
# 89 --> Blending: Ridge + DecisionTreeRegressor
# ------------------------------------------------------------
# 90 --> Blending: Ridge + DummyRegressor
# ------------------------------------------------------------
# 91 --> Blending: Ridge + LinearRegression
# ------------------------------------------------------------
# 92 --> Blending: RandomForestRegressor + ExtraTreesRegressor
# ------------------------------------------------------------
# 93 --> Blending: RandomForestRegressor + GradientBoostingRegressor
# ------------------------------------------------------------
# 94 --> Blending: RandomForestRegressor + AdaBoostRegressor
# ------------------------------------------------------------
# 95 --> Blending: RandomForestRegressor + LGBMRegressor
# ------------------------------------------------------------
# 96 --> Blending: RandomForestRegressor + KNeighborsRegressor
# ------------------------------------------------------------
# 97 --> Blending: RandomForestRegressor + PassiveAggressiveRegressor
# ------------------------------------------------------------
# 98 --> Blending: RandomForestRegressor + DecisionTreeRegressor
# ------------------------------------------------------------
# 99 --> Blending: RandomForestRegressor + DummyRegressor
# ------------------------------------------------------------
# 100 --> Blending: RandomForestRegressor + LinearRegression
# ------------------------------------------------------------
# 101 --> Blending: ExtraTreesRegressor + GradientBoostingRegressor
# ------------------------------------------------------------
# 102 --> Blending: ExtraTreesRegressor + AdaBoostRegressor
# ------------------------------------------------------------
# 103 --> Blending: ExtraTreesRegressor + LGBMRegressor
# ------------------------------------------------------------
# 104 --> Blending: ExtraTreesRegressor + KNeighborsRegressor
# ------------------------------------------------------------
# 105 --> Blending: ExtraTreesRegressor + PassiveAggressiveRegressor
# ------------------------------------------------------------
# 106 --> Blending: ExtraTreesRegressor + DecisionTreeRegressor
# ------------------------------------------------------------
# 107 --> Blending: ExtraTreesRegressor + DummyRegressor
# ------------------------------------------------------------
# 108 --> Blending: ExtraTreesRegressor + LinearRegression
# ------------------------------------------------------------
# 109 --> Blending: GradientBoostingRegressor + AdaBoostRegressor
# ------------------------------------------------------------
# 110 --> Blending: GradientBoostingRegressor + LGBMRegressor
# ------------------------------------------------------------
# 111 --> Blending: GradientBoostingRegressor + KNeighborsRegressor
# ------------------------------------------------------------
# 112 --> Blending: GradientBoostingRegressor + PassiveAggressiveRegressor
# ------------------------------------------------------------
# 113 --> Blending: GradientBoostingRegressor + DecisionTreeRegressor
# ------------------------------------------------------------
# 114 --> Blending: GradientBoostingRegressor + DummyRegressor
# ------------------------------------------------------------
# 115 --> Blending: GradientBoostingRegressor + LinearRegression
# ------------------------------------------------------------
# 116 --> Blending: AdaBoostRegressor + LGBMRegressor
# ------------------------------------------------------------
# 117 --> Blending: AdaBoostRegressor + KNeighborsRegressor
# ------------------------------------------------------------
# 118 --> Blending: AdaBoostRegressor + PassiveAggressiveRegressor
# ------------------------------------------------------------
# 119 --> Blending: AdaBoostRegressor + DecisionTreeRegressor
# ------------------------------------------------------------
# 120 --> Blending: AdaBoostRegressor + DummyRegressor
# ------------------------------------------------------------
# 121 --> Blending: AdaBoostRegressor + LinearRegression
# ------------------------------------------------------------
# 122 --> Blending: LGBMRegressor + KNeighborsRegressor
# ------------------------------------------------------------
# 123 --> Blending: LGBMRegressor + PassiveAggressiveRegressor
# ------------------------------------------------------------
# 124 --> Blending: LGBMRegressor + DecisionTreeRegressor
# ------------------------------------------------------------
# 125 --> Blending: LGBMRegressor + DummyRegressor
# ------------------------------------------------------------
# 126 --> Blending: LGBMRegressor + LinearRegression
# ------------------------------------------------------------
# 127 --> Blending: KNeighborsRegressor + PassiveAggressiveRegressor
# ------------------------------------------------------------
# 128 --> Blending: KNeighborsRegressor + DecisionTreeRegressor
# ------------------------------------------------------------
# 129 --> Blending: KNeighborsRegressor + DummyRegressor
# ------------------------------------------------------------
# 130 --> Blending: KNeighborsRegressor + LinearRegression
# ------------------------------------------------------------
# 131 --> Blending: PassiveAggressiveRegressor + DecisionTreeRegressor
# ------------------------------------------------------------
# 132 --> Blending: PassiveAggressiveRegressor + DummyRegressor
# ------------------------------------------------------------
# 133 --> Blending: PassiveAggressiveRegressor + LinearRegression
# ------------------------------------------------------------
# 134 --> Blending: DecisionTreeRegressor + DummyRegressor
# ------------------------------------------------------------
# 135 --> Blending: DecisionTreeRegressor + LinearRegression
# ------------------------------------------------------------
# 136 --> Blending: DummyRegressor + LinearRegression
# ------------------------------------------------------------

# %%
print("\nผลลัพธ์ของการ Blend Models:")
for blend, score in sorted(r2_results.items(), key=lambda x: x[1], reverse=True):  # เรียงจาก R² สูงสุด
    print(f"{blend}: {score}")
# Out:
# ผลลัพธ์ของการ Blend Models:
# OrthogonalMatchingPursuit, HuberRegressor: 0.2996
# Lasso, HuberRegressor: 0.2961
# LassoLars, HuberRegressor: 0.296
# ElasticNet, HuberRegressor: 0.2946
# Lasso, OrthogonalMatchingPursuit: 0.2941
# OrthogonalMatchingPursuit, ElasticNet: 0.2941
# BayesianRidge, HuberRegressor: 0.294
# OrthogonalMatchingPursuit, BayesianRidge: 0.2938
# OrthogonalMatchingPursuit, LassoLars: 0.2934
# Lasso, LassoLars: 0.2911
# Lasso, ElasticNet: 0.2911
# LassoLars, ElasticNet: 0.2906
# Lasso, BayesianRidge: 0.2905
# LassoLars, BayesianRidge: 0.2901
# ElasticNet, BayesianRidge: 0.2884
# HuberRegressor, ExtraTreesRegressor: 0.2801
# HuberRegressor, RandomForestRegressor: 0.2773
# OrthogonalMatchingPursuit, Ridge: 0.2764
# OrthogonalMatchingPursuit, ExtraTreesRegressor: 0.2762
# OrthogonalMatchingPursuit, RandomForestRegressor: 0.2747
# LassoLars, Ridge: 0.2726
# Lasso, Ridge: 0.2724
# HuberRegressor, Ridge: 0.2722
# HuberRegressor, GradientBoostingRegressor: 0.2718
# Lasso, ExtraTreesRegressor: 0.2704
# ElasticNet, ExtraTreesRegressor: 0.2703
# ElasticNet, RandomForestRegressor: 0.2702
# BayesianRidge, RandomForestRegressor: 0.27
# OrthogonalMatchingPursuit, GradientBoostingRegressor: 0.2695
# Lasso, RandomForestRegressor: 0.2693
# BayesianRidge, ExtraTreesRegressor: 0.2693
# LassoLars, ExtraTreesRegressor: 0.2689
# LassoLars, RandomForestRegressor: 0.2679
# ElasticNet, Ridge: 0.2677
# HuberRegressor, AdaBoostRegressor: 0.2654
# ElasticNet, GradientBoostingRegressor: 0.2635
# BayesianRidge, Ridge: 0.2635
# Lasso, GradientBoostingRegressor: 0.2633
# BayesianRidge, GradientBoostingRegressor: 0.2626
# LassoLars, GradientBoostingRegressor: 0.2621
# OrthogonalMatchingPursuit, AdaBoostRegressor: 0.2542
# Ridge, RandomForestRegressor: 0.251
# OrthogonalMatchingPursuit, LGBMRegressor: 0.2471
# ElasticNet, AdaBoostRegressor: 0.2468
# Lasso, AdaBoostRegressor: 0.246
# BayesianRidge, AdaBoostRegressor: 0.2458
# Ridge, ExtraTreesRegressor: 0.2458
# HuberRegressor, LGBMRegressor: 0.2454
# LassoLars, AdaBoostRegressor: 0.244
# Ridge, GradientBoostingRegressor: 0.2405
# Lasso, LGBMRegressor: 0.2389
# ElasticNet, LGBMRegressor: 0.2382
# LassoLars, LGBMRegressor: 0.2381
# BayesianRidge, LGBMRegressor: 0.2374
# Ridge, AdaBoostRegressor: 0.2295
# HuberRegressor, KNeighborsRegressor: 0.2187
# Ridge, LGBMRegressor: 0.2061
# OrthogonalMatchingPursuit, KNeighborsRegressor: 0.2039
# ElasticNet, KNeighborsRegressor: 0.2032
# Lasso, KNeighborsRegressor: 0.2019
# BayesianRidge, KNeighborsRegressor: 0.2012
# LassoLars, KNeighborsRegressor: 0.2
# RandomForestRegressor, ExtraTreesRegressor: 0.1842
# Ridge, KNeighborsRegressor: 0.1788
# ExtraTreesRegressor, GradientBoostingRegressor: 0.1785
# RandomForestRegressor, GradientBoostingRegressor: 0.1772
# RandomForestRegressor, AdaBoostRegressor: 0.1637
# ExtraTreesRegressor, AdaBoostRegressor: 0.1619
# GradientBoostingRegressor, AdaBoostRegressor: 0.1517
# ExtraTreesRegressor, LGBMRegressor: 0.1414
# RandomForestRegressor, LGBMRegressor: 0.1396
# RandomForestRegressor, KNeighborsRegressor: 0.1256
# GradientBoostingRegressor, LGBMRegressor: 0.1212
# ElasticNet, PassiveAggressiveRegressor: 0.1158
# LassoLars, PassiveAggressiveRegressor: 0.1157
# Lasso, PassiveAggressiveRegressor: 0.1153
# BayesianRidge, PassiveAggressiveRegressor: 0.1129
# OrthogonalMatchingPursuit, PassiveAggressiveRegressor: 0.1122
# AdaBoostRegressor, LGBMRegressor: 0.11
# HuberRegressor, PassiveAggressiveRegressor: 0.1087
# GradientBoostingRegressor, KNeighborsRegressor: 0.1086
# ExtraTreesRegressor, KNeighborsRegressor: 0.1054
# RandomForestRegressor, PassiveAggressiveRegressor: 0.0988
# HuberRegressor, DummyRegressor: 0.086
# ExtraTreesRegressor, PassiveAggressiveRegressor: 0.0761
# AdaBoostRegressor, KNeighborsRegressor: 0.0749
# Ridge, PassiveAggressiveRegressor: 0.0682
# LGBMRegressor, KNeighborsRegressor: 0.0682
# OrthogonalMatchingPursuit, DecisionTreeRegressor: 0.064
# GradientBoostingRegressor, PassiveAggressiveRegressor: 0.0625
# HuberRegressor, DecisionTreeRegressor: 0.0621
# Lasso, DecisionTreeRegressor: 0.0583
# ElasticNet, DecisionTreeRegressor: 0.0577
# LassoLars, DecisionTreeRegressor: 0.0571
# AdaBoostRegressor, PassiveAggressiveRegressor: 0.0563
# BayesianRidge, DecisionTreeRegressor: 0.0553
# OrthogonalMatchingPursuit, DummyRegressor: 0.05
# ElasticNet, DummyRegressor: 0.0454
# BayesianRidge, DummyRegressor: 0.0423
# Lasso, DummyRegressor: 0.0419
# Ridge, DummyRegressor: 0.0385
# LGBMRegressor, PassiveAggressiveRegressor: 0.0377
# LassoLars, DummyRegressor: 0.0372
# Ridge, DecisionTreeRegressor: 0.0255
# ExtraTreesRegressor, DecisionTreeRegressor: -0.0448
# GradientBoostingRegressor, DecisionTreeRegressor: -0.0451
# AdaBoostRegressor, DecisionTreeRegressor: -0.0509
# RandomForestRegressor, DecisionTreeRegressor: -0.0522
# RandomForestRegressor, DummyRegressor: -0.065
# ExtraTreesRegressor, DummyRegressor: -0.0846
# GradientBoostingRegressor, DummyRegressor: -0.0903
# LGBMRegressor, DecisionTreeRegressor: -0.0944
# LGBMRegressor, DummyRegressor: -0.109
# KNeighborsRegressor, PassiveAggressiveRegressor: -0.1263
# KNeighborsRegressor, DecisionTreeRegressor: -0.1296
# PassiveAggressiveRegressor, DecisionTreeRegressor: -0.1374
# PassiveAggressiveRegressor, DummyRegressor: -0.1677
# AdaBoostRegressor, DummyRegressor: -0.1713
# KNeighborsRegressor, DummyRegressor: -0.2366
# DecisionTreeRegressor, DummyRegressor: -0.3323
# PassiveAggressiveRegressor, LinearRegression: -5.439127934299069e+20
# LGBMRegressor, LinearRegression: -5.439127934306733e+20
# GradientBoostingRegressor, LinearRegression: -5.439127934307067e+20
# OrthogonalMatchingPursuit, LinearRegression: -5.4391279343074764e+20
# HuberRegressor, LinearRegression: -5.439127934307995e+20
# ElasticNet, LinearRegression: -5.4391279343087197e+20
# Lasso, LinearRegression: -5.4391279343090296e+20
# LassoLars, LinearRegression: -5.4391279343090296e+20
# BayesianRidge, LinearRegression: -5.439127934309689e+20
# KNeighborsRegressor, LinearRegression: -5.4391279343106084e+20
# RandomForestRegressor, LinearRegression: -5.439127934311756e+20
# AdaBoostRegressor, LinearRegression: -5.439127934312324e+20
# ExtraTreesRegressor, LinearRegression: -5.4391279343126046e+20
# Ridge, LinearRegression: -5.439127934312682e+20
# DecisionTreeRegressor, LinearRegression: -5.4391279343167675e+20
# DummyRegressor, LinearRegression: -5.4391279343225786e+20

# %% [markdown]
# # Predict 1 by 1

# %%
data_compare = data_filtered.loc[:'2025-01-12']
result = pd.DataFrame()

start_date = "2025-01-13"
end_date = "2025-2-11"

for date in pd.date_range(start=start_date, end=end_date, freq="D"):
    # Drop columns
    test_1 = data_filtered.drop(columns=['pm_10','pm_10_rolling_2', 'pm_10_rolling_3', 'pm_10_rolling_5',
        'pm_10_rolling_7', 'pm_10_lag_1', 'pm_10_lag_2', 'pm_10_lag_3',
        'pm_10_lag_5', 'pm_10_lag_7'])

    # ดึงวันนี้มา
    test_1 = test_1.loc[str(date.date())]

    # ใส่เข้าไป
    data_compare = pd.concat([data_compare, test_1], axis=0)
    
        # คำนวณ
    data_compare['pm_10_rolling_2'] = data_compare['pm_10'].rolling(window=2).mean().shift(1)  # ค่าเฉลี่ย 2 วันของ PM 10
    data_compare['pm_10_rolling_3'] = data_compare['pm_10'].rolling(window=3).mean().shift(1)  # ค่าเฉลี่ย 3 วันของ PM 10
    data_compare['pm_10_rolling_5'] = data_compare['pm_10'].rolling(window=5).mean().shift(1)  # ค่าเฉลี่ย 5 วันของ PM 10
    data_compare['pm_10_rolling_7'] = data_compare['pm_10'].rolling(window=7).mean().shift(1)

    data_compare['pm_10_lag_1'] = data_compare['pm_10'].shift(1)
    data_compare['pm_10_lag_2'] = data_compare['pm_10'].shift(2)
    data_compare['pm_10_lag_3'] = data_compare['pm_10'].shift(3)
    data_compare['pm_10_lag_5'] = data_compare['pm_10'].shift(5)
    data_compare['pm_10_lag_7'] = data_compare['pm_10'].shift(7)

    # ดึง
    test_1 = (data_compare.loc[str(date.date())]).drop(columns=['pm_10'])
    test_1[['pm_10_rolling_2', 'pm_10_rolling_3', 'pm_10_rolling_5',
        'pm_10_rolling_7', 'pm_10_lag_1', 'pm_10_lag_2', 'pm_10_lag_3',
        'pm_10_lag_5', 'pm_10_lag_7']]
    
    # Drop ทิ้งล่าสุดใน data_compare
    data_compare = data_compare.drop(data_compare.last_valid_index())
    test_1 = test_1[~test_1.index.duplicated(keep='last')]

    # Predict
    predict_test_1 = exp1.predict_model(tune_1, data=test_1)

        # เพิ่มผลทำนายเข้าไปใน data_compare
    data_compare = pd.concat([data_compare, predict_test_1], axis=0)

    # แทนที่ค่าในคอลัมน์ 'pm_10' ในวันที่ '2025-01-13' ด้วยค่าในคอลัมน์ 'prediction_label'
    data_compare.loc[str(date.date()), 'pm_10'] = data_compare.loc[str(date.date()), 'prediction_label']

    # ลบคอลัมน์ 'prediction_label' (หากต้องการแค่ผลทำนาย)
    data_compare = data_compare.drop(columns=['prediction_label'])

    # กรองเอาวันที่ซ้ำกัน (index ซ้ำ) ออกให้เหลือแค่ตัวเดียว
    data_compare = data_compare[~data_compare.index.duplicated(keep='last')]

    # บันทึกลง result
    result = pd.concat([result, predict_test_1], axis=0)

# %%
data_compare.tail(30)[['pm_10','pm_10_rolling_2', 'pm_10_rolling_3', 'pm_10_rolling_5',
